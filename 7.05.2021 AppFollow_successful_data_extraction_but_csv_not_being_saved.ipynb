# %%
from appfollow_api import list_URL
from variable_auth import secretkey
from af_meta_data import af_app_data_extraction
from af_process_idle import af_data_process
data=af_app_data_extraction(list_URL, secretkey)
app_follow_data=af_data_process(data)

# %%
app_follow_data.columns
# Out:
# Index(['has_reply_integration', 'watch_url', 'count_reviews', 'store',
#        'app_id', 'count_whatsnew', 'created', 'is_favorite', 'app.artist_name',
#        'app.version', 'app.title', 'app.lang', 'app.country', 'app.icon',
#        'app.id', 'ext_id', 'app.genre', 'app.has_iap', 'app.release_date',
#        'app.type', 'app.size', 'app.url', 'app.kind'],
#       dtype='object')

# %%
app_follow_data
# Out:
#     has_reply_integration                                          watch_url  \
# 0                       0  https://watch.appfollow.io/apps/skidos-ios-por...
# 1                       0  https://watch.appfollow.io/apps/skidos-ios-por...
# 2                       0  https://watch.appfollow.io/apps/skidos-ios-por...
# 3                       0  https://watch.appfollow.io/apps/skidos-ios-por...
# 4                       1  https://watch.appfollow.io/apps/skidos-ios-por...
# ..                    ...                                                ...
# 63                      1  https://watch.appfollow.io/apps/skidos-ios-por...
# 64                      0  https://watch.appfollow.io/apps/skidos-ios-por...
# 65                      0  https://watch.appfollow.io/apps/skidos-ios-por...
# 66                      0  https://watch.appfollow.io/apps/skidos-ios-por...
# 67                      0  https://watch.appfollow.io/apps/skidos-ios-por...
#
#     count_reviews   store   app_id  count_whatsnew              created  \
# 0             779  itunes    29907             100  2019-09-06 19:20:57
# 1            1848  itunes   126065             103  2020-05-12 17:16:24
# 2            4745  itunes   126826              10  2021-01-26 18:22:33
# 3            1058  itunes   355486              34  2020-03-30 21:31:19
# 4             108  itunes   385810              18  2019-03-02 22:21:41
# ..            ...     ...      ...             ...                  ...
# 63              0  itunes  1378925               0  2021-04-08 10:03:18
# 64              0  itunes  1388489               0  2021-04-09 11:38:06
# 65             27  itunes  1425769               0  2021-04-16 13:28:02
# 66           6227  itunes  1627085               0  2021-05-04 10:37:51
# 67           3666  itunes  1627086               0  2021-05-04 10:37:59
#
#     is_favorite                                    app.artist_name  \
# 0             1                                     StudyPad, Inc.
# 1             1                        IDZ Digital Private Limited
# 2             0                                        MagisterApp
# 3             1                                     StudyPad, Inc.
# 4             1                                    Skidos Learning
# ..          ...                                                ...
# 63            0                                    Skidos Learning
# 64            0                                    Skidos Learning
# 65            0                                     StudyPad, Inc.
# 66            0  Hong Hai Wu Xian Technology Development Co., Ltd.
# 67            0                               Turbo Chilli Pty Ltd
#
#    app.version  ...                                           app.icon  \
# 0       5.9.28  ...  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 1       27.5.2  ...  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 2        1.7.3  ...  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 3        5.5.9  ...  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 4          4.8  ...  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# ..         ...  ...                                                ...
# 63         1.0  ...  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 64         1.0  ...  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 65       3.1.6  ...  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 66       1.2.7  ...  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
# 67         1.5  ...  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
#
#      app.id      ext_id  app.genre  app.has_iap  app.release_date app.type  \
# 0     29907   672658828  Education            1        2021-04-09     free
# 1    126065   533412119  Education            1        2021-04-09     free
# 2    126826   514963431      Games            1        2017-01-31     free
# 3    355486   463469532  Education            1        2020-03-25     free
# 4    385810  1355644438  Education            1        2021-01-19     free
# ..      ...         ...        ...          ...               ...      ...
# 63  1378925  1551104516  Education            1        2021-03-29     free
# 64  1388489  1557244765  Education            1        2021-04-08     free
# 65  1425769   973058286  Education            1        2021-02-02     free
# 66  1627085  1461045706      Games            0        2019-04-28     free
# 67  1627086   769574372      Games            0        2014-01-22     free
#
#     app.size                                            app.url   app.kind
# 0      696.0  https://apps.apple.com/us/app/splashlearn-kids...  universal
# 1      414.0  https://apps.apple.com/us/app/kidloland-kids-t...  universal
# 2       28.0  https://apps.apple.com/us/app/savanna-animals-...  universal
# 3      332.0  https://apps.apple.com/us/app/1st-grade-math-l...  universal
# 4      416.0  https://apps.apple.com/us/app/cool-math-games-...  universal
# ..       ...                                                ...        ...
# 63     400.0  https://apps.apple.com/us/app/matching-puzzles...  universal
# 64     752.0  https://apps.apple.com/us/app/toddler-puzzle-g...  universal
# 65     119.0  https://apps.apple.com/us/app/splashlearn-pare...     iphone
# 66      73.0  https://apps.apple.com/us/app/unblock-ball-blo...
# 67      65.0  https://apps.apple.com/us/app/unroll-me/id7695...
#
# [68 rows x 23 columns]
