# %%
import pandas as pd
from config import path_to_key, key_id, issuer_id, appstore_url
from appstore_auth import get_token
from appstore_data import app_store_data_extraction
from appstore_meta_data_process import appstore_processed_data
token=get_token(path_to_key, key_id, issuer_id)
x=app_store_data_extraction(token, appstore_url)
appstore_processed_data(x)
# Out:
#     type      ext_id                                    attributes.name  \
# 0   apps  1439176833                      Kids Math 1st, 2nd, 3rd Grade
# 1   apps  1326861131                     Addition, Subtraction for Kids
# 2   apps  1565994951                                Roll That Ball Game
# 3   apps  1506886061                             Doctor Games: for Kids
# 4   apps  1497549298                     Fun Games: Kids Preschool Math
# ..   ...         ...                                                ...
# 71  apps  1551104363                      Toddler Shapes Game: Learning
# 72  apps  1551104516                       Matching Puzzles for Kids 3+
# 73  apps  1551104686                     Kids Building & Learning Games
# 74  apps   733707729  Milk Hunt: Fun Kids Math Learning Game for Gra...
# 75  apps   906245761                      Math Learning Games: For Kids
#
#                        attributes.bundleId attributes.sku  \
# 0                      skidos.rabbitrescue         000075
# 1                           skidos.surffun         000059
# 2       skidos.ball.slide.kids.puzzle.game         000111
# 3        skidos.preschool.kids.doctor.game         000092
# 4   skidos.shopping.toddler.learning.games         000089
# ..                                     ...            ...
# 71             skidos.toddler.smart.shapes         000107
# 72            skidos.fairy.baby.bocks.game         000108
# 73            skidos.construction.set.kids         000109
# 74                         skidos.milkhunt           0001
# 75                     skidos.milkhuntgame           0002
#
#    attributes.primaryLocale  attributes.isOrEverWasMadeForKids  \
# 0                     en-US                               True
# 1                     en-US                               True
# 2                     en-US                              False
# 3                     en-US                               True
# 4                     en-US                               True
# ..                      ...                                ...
# 71                    en-US                               True
# 72                    en-US                               True
# 73                    en-US                               True
# 74                    en-US                               True
# 75                    en-US                               True
#
#     attributes.availableInNewTerritories attributes.contentRightsDeclaration  \
# 0                                   True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 1                                   True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 2                                  False                                None
# 3                                   True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 4                                   True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# ..                                   ...                                 ...
# 71                                  True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 72                                  True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 73                                  True    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 74                                 False    DOES_NOT_USE_THIRD_PARTY_CONTENT
# 75                                  True    DOES_NOT_USE_THIRD_PARTY_CONTENT
#
#                  relationships.betaTesters.links.self  ...  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...  ...
# ..                                                ...  ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...  ...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...  ...
#
#                       relationships.prices.links.self  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#                    relationships.prices.links.related  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#         relationships.availableTerritories.links.self  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#      relationships.availableTerritories.links.related  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#               relationships.inAppPurchases.links.self  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#            relationships.inAppPurchases.links.related  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#    relationships.gameCenterEnabledVersions.links.self  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#    relationships.gameCenterEnabledVersions.links.related  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#          relationships.perfPowerMetrics.links.related  \
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
#                                            links.self
# 0   https://api.appstoreconnect.apple.com/v1/apps/...
# 1   https://api.appstoreconnect.apple.com/v1/apps/...
# 2   https://api.appstoreconnect.apple.com/v1/apps/...
# 3   https://api.appstoreconnect.apple.com/v1/apps/...
# 4   https://api.appstoreconnect.apple.com/v1/apps/...
# ..                                                ...
# 71  https://api.appstoreconnect.apple.com/v1/apps/...
# 72  https://api.appstoreconnect.apple.com/v1/apps/...
# 73  https://api.appstoreconnect.apple.com/v1/apps/...
# 74  https://api.appstoreconnect.apple.com/v1/apps/...
# 75  https://api.appstoreconnect.apple.com/v1/apps/...
#
# [76 rows x 40 columns]
