# %%
from config import path_to_key, key_id, issuer_id, appstore_url
from appstore_auth import get_token
from appstore_data import app_store_data_extraction
from appstore_meta_data_process import appstore_processed_data
token=get_token(path_to_key, key_id, issuer_id)
x=app_store_data_extraction(token, appstore_url)
appstore_processed_data(x)
# Out:
#     type          id                                         attributes  \
# 0   apps  1439176833  {'name': 'Kids Math 1st, 2nd, 3rd Grade', 'bun...
# 1   apps  1326861131  {'name': 'Addition, Subtraction for Kids', 'bu...
# 2   apps  1565994951  {'name': 'Roll That Ball Game', 'bundleId': 's...
# 3   apps  1506886061  {'name': 'Doctor Games: for Kids', 'bundleId':...
# 4   apps  1497549298  {'name': 'Fun Games: Kids Preschool Math', 'bu...
# ..   ...         ...                                                ...
# 71  apps  1551104363  {'name': 'Toddler Shapes Game: Learning', 'bun...
# 72  apps  1551104516  {'name': 'Matching Puzzles for Kids 3+', 'bund...
# 73  apps  1551104686  {'name': 'Kids Building & Learning Games', 'bu...
# 74  apps   733707729  {'name': 'Milk Hunt: Fun Kids Math Learning Ga...
# 75  apps   906245761  {'name': 'Math Learning Games: For Kids', 'bun...
#
#                                         relationships  \
# 0   {'betaTesters': {'links': {'self': 'https://ap...
# 1   {'betaTesters': {'links': {'self': 'https://ap...
# 2   {'betaTesters': {'links': {'self': 'https://ap...
# 3   {'betaTesters': {'links': {'self': 'https://ap...
# 4   {'betaTesters': {'links': {'self': 'https://ap...
# ..                                                ...
# 71  {'betaTesters': {'links': {'self': 'https://ap...
# 72  {'betaTesters': {'links': {'self': 'https://ap...
# 73  {'betaTesters': {'links': {'self': 'https://ap...
# 74  {'betaTesters': {'links': {'self': 'https://ap...
# 75  {'betaTesters': {'links': {'self': 'https://ap...
#
#                                                 links
# 0   {'self': 'https://api.appstoreconnect.apple.co...
# 1   {'self': 'https://api.appstoreconnect.apple.co...
# 2   {'self': 'https://api.appstoreconnect.apple.co...
# 3   {'self': 'https://api.appstoreconnect.apple.co...
# 4   {'self': 'https://api.appstoreconnect.apple.co...
# ..                                                ...
# 71  {'self': 'https://api.appstoreconnect.apple.co...
# 72  {'self': 'https://api.appstoreconnect.apple.co...
# 73  {'self': 'https://api.appstoreconnect.apple.co...
# 74  {'self': 'https://api.appstoreconnect.apple.co...
# 75  {'self': 'https://api.appstoreconnect.apple.co...
#
# [76 rows x 5 columns]
